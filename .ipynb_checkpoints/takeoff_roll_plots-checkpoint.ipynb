# %%
import plotly.express as px
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from os.path import expanduser
import os.path 
import numpy as np
import webbrowser as wb

#TODO: propagate detailed aircraft type
home = expanduser("~")
filepath = home+'\OneDrive - DOT OST\BADA4_Reduced_Thrust_Sensor_Path_Noise_Comparison_main'#\\FDR_desensitized\\TKOFF'
# filepath = home+'\OneDrive\Documents\takeoff_thrust\FDR_desensitized\TKOFF'
filename = 'takeoff_distance_A320_A330_A340'#_kluge'
file_extension = '.csv'
df = pd.read_csv(os.path.join(filepath, filename + file_extension), index_col=["FLIGHT_ID", "TIME_OFFSET"])
df.rename(
    columns={'HEAD_WIND':'HEAD_WIND_KNOTS'
             ,'FUEL_QUANTITY':'FUEL_QUANTITY_KILOGRAMS'
             ,'P64  Air Temperature (outside) at Start of Event (library) (Deg Celsius)':'AIR_TEMP_OUTSIDE_CELSIUS'
            }
    , inplace=True)

# %%
def scatter_plot(df_schedule, color_field = "APT_AIRCRAFT_RUNWAY_STAGE" ):
    #TODO:make this a function
    x_max = stated_max = df_schedule.DISTANCE_FROM_RUNWAY_END_liftoff.max()
    x_min = stated_min = df_schedule.DISTANCE_FROM_RUNWAY_END_liftoff.min()
    y_max = detected_max = df_schedule.DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF.max()
    y_min = detected_min = df_schedule.DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF.min()

    perfect_fit_min = x_min if x_min < y_min else y_min
    perfect_fit_max = x_max if x_max > y_max else y_max

    fig = px.scatter(
        df_schedule.reset_index(level = ["FLIGHT_ID"])
        , title='Liftoff distance from runway end (feet)'
        , x='DISTANCE_FROM_RUNWAY_END_liftoff'
        ,y='DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF'
        , color=color_field
        , labels = {'DISTANCE_FROM_RUNWAY_END_liftoff':'As stated in CFDR',
                    'DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF':'As detected from trajectory',
                    'APT_AIRCRAFT_RUNWAY_STAGE': 'Airport / Aicraft Type / Runway / Stage Length ID'
                   }
        , hover_data= ['FLIGHT_ID']#, 'DISTANCE_FROM_RUNWAY_END', 'DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF']
        , opacity = 0.6
    )

    fig.add_trace(
        go.Scatter(
            x = [perfect_fit_min, perfect_fit_max]
            , y = [perfect_fit_min, perfect_fit_max]
            , mode = "lines"
            , name = 'Perfect Fit'
            , line = go.scatter.Line(color = 'black', dash = 'dash')
            , opacity=0.4
        )
    )

    fig.add_trace(
        go.Scatter(
            x = [perfect_fit_min, perfect_fit_max]
            , y = [perfect_fit_min-275, perfect_fit_max-275]
            , mode = "lines"
            , name = 'Perfect Fit - 275 ft (a.k.a detected liftoff one second before actual)'
            , line = go.scatter.Line(color = 'black', dash = 'longdash')
            , opacity=0.4
        )

    )


    fig.add_trace(
        go.Scatter(
            x = [perfect_fit_min, perfect_fit_max]
            , y = [perfect_fit_min-550, perfect_fit_max-550]
            , mode = "lines"
            , name = 'Perfect Fit - 550 ft (a.k.a detected liftoff two seconds before actual)'
            , line = go.scatter.Line(color = 'purple', dash = 'longdashdot')
            , opacity=0.4
        )

    )

    fig.add_trace(
        go.Scatter(
            x = [perfect_fit_min, perfect_fit_max]
            , y = [perfect_fit_min+275, perfect_fit_max+275]
            , mode = "lines"
            , name = 'Perfect Fit + 275 ft (a.k.a detected liftoff one second after actual)'
            , line = go.scatter.Line(color = 'black', dash = 'longdash')
            , opacity=0.4
        )

    )

    fig.add_trace(
        go.Scatter(
            x = [perfect_fit_min, perfect_fit_max]
            , y = [perfect_fit_min+550, perfect_fit_max+550]
            , mode = "lines"
            , name = 'Perfect Fit + 550 ft (a.k.a detected liftoff two seconds after actual)'
            , line = go.scatter.Line(color = 'purple', dash = 'longdashdot')
            , opacity=0.4
        )

    )

    fig.update_yaxes(
    #     scaleanchor = "x",
        scaleratio = 1,
      )
    
    return fig

# %%
def plot_metrics_for_individual_flights(dataframe, flight_sample_size = 10):

    metric_maxes = {}

    plotbook_filename = 'plotbook' + '_' + str(flight_sample_size) if flight_sample_size != -1 else 'plotbook'
    df = dataframe
    if 'FLIGHT_ID' in df.columns:
        df_grouped_by_flight = df.drop(columns = ['FLIGHT_ID'], axis = 1).groupby("FLIGHT_ID")
        df["FLIGHT_ID"] = df["FLIGHT_ID"].astype(str)
    else:
        df_grouped_by_flight = df.groupby("FLIGHT_ID")
    
    fn = plotbook_filename + '.html'
    open( os.path.join(filepath,fn), 'w')
    #     #TODO: write plots to pdf file
    #     fn = plotbook_filename + '.pdf'

    flight_count = 0
    for flight, group in df_grouped_by_flight:
        flight_sample_size = len(group) if flight_sample_size == -1 else flight_sample_size

        if flight_count == flight_sample_size:
            break

#         metrics = ['MSL_ALT']
        metrics = ['AFE_ALT']
        metrics += ['N1', 'TAS_SEGMENT']

        #create Figure with subplots for each metric for a given flight
        fig = make_subplots(rows=len(metrics), cols=1,
                        shared_xaxes=True,
                        vertical_spacing=0.02)

        for m in metrics:
            metric_maxes[m]=group[m].max() if m != 'N1' else 100

            #create and add a subplot to the Figure
            sub = go.Scatter(
                    x=group.DISTANCE_FROM_RUNWAY_END
                    , y=group[m]
                    , mode="markers"
                    , name = m
            )
            fig.add_trace(sub, row=metrics.index(m)+1, col=1)

    #         #turn off auto range adjustment
    #         fig.update_layout(
    #             yaxis_autorange = False
    #             )        
    #         fig.update_yaxes({}, row=metrics.index(m)+1, col=1)

            dl_cgtd = detected_liftoff_cumul_grnd_trk_dist = df_liftoff.loc[flight,"DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF"]
            fig.add_trace(
                go.Scatter(
                    x=[dl_cgtd, dl_cgtd]
                    , y=[0,metric_maxes[m]]
                    , mode = "lines"
                    , name = "Detected Liftoff"
                    , line = go.scatter.Line(color = 'gray')
                )
                , row=metrics.index(m)+1, col=1 
            )        

            rprt_liftoff_cgtd = reported_liftoff_cumul_grnd_trk_dist = df_liftoff.loc[flight,"DISTANCE_FROM_RUNWAY_END"]
            fig.add_trace(
                go.Scatter(
                    x=[rprt_liftoff_cgtd, rprt_liftoff_cgtd]
                    , y=[0,metric_maxes[m]]
                    , mode = "lines"
                    , name = "Reported Liftoff"
                    , line = go.scatter.Line(color = 'orange', dash = 'dash')
                )
                , row=metrics.index(m)+1, col=1 
            )

            fig.layout.yaxis.update(title_text = metrics[0])
            fig.layout.yaxis2.update(title_text = metrics[1], tickvals=[0] + np.arange(70,100,5))
            fig.layout.yaxis3.update(title_text = metrics[2])
            fig.layout.update(title_text = "Flight " + str(flight) + '<br>' + 'Airport / Aicraft Type / Runway / Stage Length ID: ' + 
                              str(df_liftoff.loc[flight,"APT_AIRCRAFT_RUNWAY_STAGE.1"]))
        
        #write plots to html file         
        html = fig.to_html()
        with open( os.path.join(filepath,fn), 'a') as f:
            f.write(html) 

        flight_count = flight_count + 1
    print(os.path.join(filepath,fn))
        
    return (os.path.join(filepath,fn))

# %%
# #optionally write the desensitized file version if you like
# df_desensitized = pd.read_csv(os.path.join(filepath+'\\FDR_desensitized\\TKOFF', filename+'_desensitized'+file_extension), index_col=["FLIGHT_ID", "TIME_OFFSET"])
# df_kluge = pd.concat([df_desensitized,df[["FUEL_QUANTITY_KILOGRAMS"]]], axis = 1)
# df_kluge.APT_encoded = df_kluge.APT_encoded.astype('str')
# df_kluge.Departure_Runway_end_encoded = df_kluge.Departure_Runway_end_encoded.astype('str')
# df_kluge.STAGE_LENGTH_ID = df_kluge.STAGE_LENGTH_ID.astype('str')
# df_grouping_series = df_kluge[["APT_encoded", "ACTYPE", "Departure_Runway_end_encoded", "STAGE_LENGTH_ID"]].dropna()
# df_kluge["APT_AIRCRAFT_RUNWAY_STAGE.1"] = df_grouping_series.apply(list, axis=1).str.join(sep='_')
# df_kluge.to_csv(path_or_buf=filepath+'\\FDR_desensitized\\TKOFF\\takeoff_distance_kluge.csv')

# %%
modes = ['Undetected','Takeoff Ground Roll']

df["Detected_Trajectory_Mode"] = modes.index('Undetected')
df.Detected_Trajectory_Mode = df.Detected_Trajectory_Mode.astype("int")

# %%
df_liftoff = pd.DataFrame(df[df.DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF.notna()])
df_liftoff.reset_index(level = 1, inplace = True)

df_rollstart = df[df.DISTANCE_FROM_RUNWAY_END_AT_DETECTED_START_OF_TAKEOFF.notna()]
df_rollstart.reset_index(level = 1, inplace = True)

# %%
#formulate flight schedule
salient_rollstart_col_list = ['DISTANCE_FROM_THRESHOLD_AT_POINT_ONE', 'DISTANCE_FROM_POINT_ONE_FEET',
       'GROUNDSPEED_AT_POINT_ONE_KNOTS', 'WELL-BEHAVED_TRAJECTORY',
#        'LATITUDE_AT_POINT_ONE', 'LONGITUDE_AT_POINT_ONE',
        'STATED_SEGMENT_START_OF_TAKEOFF',
       'DISTANCE_FROM_RUNWAY_END_AT_DETECTED_START_OF_TAKEOFF'
        ]
extraneous_schedule_columns_list = [col for col in df_rollstart.columns if col not in salient_rollstart_col_list + ["DISTANCE_FROM_RUNWAY_END", 'TIME_OFFSET','FUEL_QUANTITY_KILOGRAMS', 'HEAD_WIND_KNOTS', 'APT_AIRCRAFT_RUNWAY_STAGE.1']]

df_schedule = df_liftoff.drop(salient_rollstart_col_list, axis = 1).join(
    df_rollstart.drop(
        columns = extraneous_schedule_columns_list, axis = 1
    )
    , how = 'left'
    , lsuffix = '_liftoff' 
    , rsuffix = '_rollstart'
)

#coalesce the grouping column
mask = (df_schedule['APT_AIRCRAFT_RUNWAY_STAGE.1_liftoff'].notna())
df_schedule.loc[mask, "APT_AIRCRAFT_RUNWAY_STAGE"] = df_schedule['APT_AIRCRAFT_RUNWAY_STAGE.1_liftoff']
mask = (df_schedule['APT_AIRCRAFT_RUNWAY_STAGE.1_rollstart'].notna())
df_schedule.loc[mask, "APT_AIRCRAFT_RUNWAY_STAGE"] = df_schedule['APT_AIRCRAFT_RUNWAY_STAGE.1_rollstart']

df_schedule["TAKEOFF_GROUND_ROLL_DISTANCE_DETECTED_IN_FEET"] = df_schedule.DISTANCE_FROM_RUNWAY_END_liftoff - df_schedule.DISTANCE_FROM_RUNWAY_END_rollstart
df_schedule["liftoff_detection_quality_numerical"] = abs(df_liftoff.DISTANCE_FROM_RUNWAY_END_AT_DETECTED_LIFTOFF - df_liftoff.DISTANCE_FROM_RUNWAY_END) / df_liftoff.DISTANCE_FROM_RUNWAY_END 

#instantiate bins for grouping on the quality of liftoff detection
liftoff_detection_quality_bins = {0:"very high", 0.01:"high", 0.05:"good", 0.1:"mediocre", 1:"poor"}

labels = []
i=0
for k, v in sorted(liftoff_detection_quality_bins.items()):
    labels.append(v)
    i += 1
labels_as_tuple = tuple(labels)

df_schedule["liftoff_detection_quality_categorized"] = pd.cut(
        df_schedule["liftoff_detection_quality_numerical"]
        , list(liftoff_detection_quality_bins.keys())+[100000]
        , labels = labels_as_tuple
    )

flights_with_very_high_liftoff_detection_quality = df_schedule[df_schedule.liftoff_detection_quality_categorized == "very high"].index.to_series()

#add average N1 during detected ground roll to the schedule
df_traj_takeoff_ground_roll = df[df.Detected_Trajectory_Mode == modes.index('Takeoff Ground Roll')]
df_traj_tkoff_gd_rl_groupby = df_traj_takeoff_ground_roll.groupby(by=["FLIGHT_ID"])
df_schedule["N1_during_detected_takeoff_ground_roll"] = df_traj_tkoff_gd_rl_groupby.mean().N1

# %%
#def mark_ground_roll_segments(df, flight_id, liftoff_time_offset, rollstart_time_offset, ground_roll_mode_index):
    #return a dataframe of start and stop times by flight
#select rows where TIME_OFFSET is within TIME_OFFSET_rollstart and TIME_OFFSET_liftoff
df_aug = df.loc[:,['N1']]
df_aug = df_aug.join(df_schedule, rsuffix="_sched", how="left").reset_index(level="TIME_OFFSET")
df_aug["Detected_Ground_Roll"] = (df_aug.TIME_OFFSET >= df_aug.TIME_OFFSET_rollstart) & (df_aug.TIME_OFFSET <= df_aug.TIME_OFFSET_liftoff)
df_aug.set_index('TIME_OFFSET',append=True, inplace=True)
mask = (df_aug.Detected_Ground_Roll == True)
df.loc[mask, 'Detected_Trajectory_Mode'] = modes.index('Takeoff Ground Roll')

# %% [markdown]
#  len(df[df["WELL-BEHAVED_TRAJECTORY"] == 1]) rows in the sample are well-behaved

# %%
inp_vars = ["HEAD_WIND_KNOTS_liftoff", "FUEL_QUANTITY_KILOGRAMS_rollstart", "AIR_TEMP_OUTSIDE_CELSIUS"]
head_wind_bin_width = 2.5
#create the categorizations of input vars including numerical bins on the input variables in inp_vars list
df_schedule_groupby = df_schedule.groupby(by="APT_AIRCRAFT_RUNWAY_STAGE") 
df_schedule_bins = pd.DataFrame(
    index=pd.Index(df_schedule_groupby.indices.keys(), name = "APT_AIRCRAFT_RUNWAY_STAGE")
    , columns=inp_vars) #for holding the bin definitions

for i in inp_vars:
    frame = pd.DataFrame()
    num_bins = bin_width = 0
    for group, inp_var in df_schedule_groupby:

        if i == "FUEL_QUANTITY_KILOGRAMS_rollstart":
            bin_width = 0.015*inp_var[i].max()
        elif i == "HEAD_WIND_KNOTS_liftoff":
            bin_width = head_wind_bin_width 
        elif i == "AIR_TEMP_OUTSIDE_CELSIUS":
            bin_sequence = [0,(80-32)*5/9,1000]       
        else:
            num_bins = 10
        
        if bin_width > 0:
            num_bins = 1 + int((inp_var[i].max() - inp_var[i].min()) / bin_width)
        
        bins = num_bins if num_bins > 0 else bin_sequence

        print(group, i, "bins ", bins, sep='-->') #testing
        #pass the group-inp_var combo as a series extracted from the groupby object
        var_group_combo_as_series = pd.Series(inp_var[i], name=i)
        (var_group_combo_binned, bins) = pd.cut(var_group_combo_as_series
                           , bins
                           , labels=False
                           , retbins=True
                          )

        var_group_combo_binned = var_group_combo_binned.to_frame(name=i)
        #store the rows or columns
        frame = pd.concat([frame, var_group_combo_binned], axis = 0)

        #store the category definitions
        df_schedule_bins.loc[group, i] = bins
    
    df_schedule[i+"_BIN"] = frame
# Out:
# CYUL_A330_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# CYUL_A330_28_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# CYUL_A330_32_5-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# CYUL_A340_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# EBBR_A319/20/21_28_1-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# EBBR_A319/20/21_32_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# EGLL_A319/20/21_10_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# EGLL_A319/20/21_23_1-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# EGLL_A319/20/21_28_1-->HEAD_WIND_KNOTS_liftoff-->bins -->11
# EGLL_A319/20/21_32_1-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# EGLL_A319/20/21_34_1-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# EHAM_A319/20/21_10_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# EHAM_A319/20/21_28_1-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# EHAM_A319/20/21_32_1-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# ESSA_A319/20/21_10_2-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# ESSA_A319/20/21_16_2-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# ESSA_A319/20/21_28_2-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# ESSA_A319/20/21_32_2-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# ESSA_A319/20/21_34_2-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# FKKD_A330_10_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# FKKD_A330_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# FKKD_A330_19_1-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# FKKD_A330_28_5-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# FKKD_A330_32_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# FKYS_A330_12_1-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# HKJK_A330_10_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# HKJK_A330_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# KBOS_A330_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KBOS_A330_32_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KBOS_A340_10_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# KBOS_A340_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# KBOS_A340_28_5-->HEAD_WIND_KNOTS_liftoff-->bins -->12
# KBOS_A340_34_5-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# KJFK_A330_06R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# KJFK_A330_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# KJFK_A330_23_5-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# KJFK_A330_32_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KJFK_A330_34_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# KJFK_A340_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# KJFK_A340_34_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# KLAX_A340_16_7-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# KLAX_A340_34_7-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KMIA_A330_16_6-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# KMIA_A330_32_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# KMIA_A340_16_6-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# KMIA_A340_34_6-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# KORD_A330_16_6-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KORD_A330_32_6-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# KORD_A330_34_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# KORD_A340_16_6-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KORD_A340_34_6-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# KSFO_A340_16_7-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# KSFO_A340_34_7-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LEBL_A319/20/21_23_1-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LEBL_A319/20/21_28_1-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LEBL_A319/20/21_32_1-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LEMD_A319/20/21_10_2-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LEMD_A319/20/21_16_2-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LEMD_A319/20/21_28_2-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LLBG_A330_10_4-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LLBG_A330_16_4-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LLBG_A330_26L_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LLBG_A330_28_4-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LLBG_A330_32_4-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LLBG_A330_34_4-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LLBG_A340_10_4-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# LLBG_A340_16_4-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LLBG_A340_28_4-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LLBG_A340_34_4-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSGG_A319/20/21_07R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# LSGG_A319/20/21_10_1-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSGG_A319/20/21_25L_1-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSGG_A319/20/21_27L_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSGG_A319/20/21_27R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LSGG_A319/20/21_28_1-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# LSGG_A319/20/21_32_1-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LSGG_A319/20/21_34_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSGG_A330_04L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSGG_A330_13R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSGG_A330_22R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSGG_A330_31L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A319/20/21_01L_2-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSZH_A319/20/21_07R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A319/20/21_09R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A319/20/21_15L_2-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A319/20/21_18L_1-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A319/20/21_19R_2-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A319/20/21_23_1-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A319/20/21_24_1-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSZH_A319/20/21_25L_1-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A319/20/21_25R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A319/20/21_27L_1-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# LSZH_A319/20/21_27R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A330_04L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->13
# LSZH_A330_04R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A330_06L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A330_06R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# LSZH_A330_08R_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A330_12L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A330_12R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSZH_A330_12_4-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A330_12_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# LSZH_A330_13R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A330_14L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSZH_A330_14_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A330_15R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A330_22L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A330_22L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A330_22R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->12
# LSZH_A330_24L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->13
# LSZH_A330_24R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# LSZH_A330_26_4-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A330_27_6-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A330_28_6-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSZH_A330_30L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A330_30R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A330_30_4-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A330_31L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSZH_A330_32L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSZH_A330_32R_6-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A330_33L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSZH_A340_01R_7-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A340_03L_7-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# LSZH_A340_04L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# LSZH_A340_04R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A340_06R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_06R_7-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_08L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_08R_6-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A340_10L_7-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_10R_7-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_10_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_12_4-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSZH_A340_12_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_13R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A340_14L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# LSZH_A340_15R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A340_21R_7-->HEAD_WIND_KNOTS_liftoff-->bins -->9
# LSZH_A340_22L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# LSZH_A340_22L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# LSZH_A340_22R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# LSZH_A340_24L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A340_24L_7-->HEAD_WIND_KNOTS_liftoff-->bins -->13
# LSZH_A340_24R_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# LSZH_A340_25R_7-->HEAD_WIND_KNOTS_liftoff-->bins -->13
# LSZH_A340_26_4-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# LSZH_A340_27_6-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A340_28L_7-->HEAD_WIND_KNOTS_liftoff-->bins -->11
# LSZH_A340_28R_7-->HEAD_WIND_KNOTS_liftoff-->bins -->8
# LSZH_A340_28_6-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LSZH_A340_30_4-->HEAD_WIND_KNOTS_liftoff-->bins -->3
# LSZH_A340_32L_6-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# LSZH_A340_32R_6-->HEAD_WIND_KNOTS_liftoff-->bins -->11
# LSZH_A340_33L_5-->HEAD_WIND_KNOTS_liftoff-->bins -->10
# OMDB_A330_10_5-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# OMDB_A330_16_5-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# OMDB_A330_26_1-->HEAD_WIND_KNOTS_liftoff-->bins -->5
# OMDB_A330_28_5-->HEAD_WIND_KNOTS_liftoff-->bins -->2
# OMDB_A330_32_5-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# OOMS_A330_12R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->4
# OOMS_A330_30R_1-->HEAD_WIND_KNOTS_liftoff-->bins -->6
# VABB_A330_16_6-->HEAD_WIND_KNOTS_liftoff-->bins -->7
# VABB_A330_34_6-->HEAD_WIND_KNOTS_liftoff-->bins -->1
# CYUL_A330_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->13
# CYUL_A330_28_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# CYUL_A330_32_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# CYUL_A340_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# EBBR_A319/20/21_28_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->32
# EBBR_A319/20/21_32_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# EGLL_A319/20/21_10_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# EGLL_A319/20/21_23_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# EGLL_A319/20/21_28_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->21
# EGLL_A319/20/21_32_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# EGLL_A319/20/21_34_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# EHAM_A319/20/21_10_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# EHAM_A319/20/21_28_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->17
# EHAM_A319/20/21_32_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# ESSA_A319/20/21_10_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# ESSA_A319/20/21_16_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# ESSA_A319/20/21_28_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# ESSA_A319/20/21_32_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# ESSA_A319/20/21_34_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->19
# FKKD_A330_10_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# FKKD_A330_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# FKKD_A330_19_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# FKKD_A330_28_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# FKKD_A330_32_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->5
# FKYS_A330_12_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->22
# HKJK_A330_10_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# HKJK_A330_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->13
# KBOS_A330_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# KBOS_A330_32_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# KBOS_A340_10_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# KBOS_A340_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# KBOS_A340_28_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# KBOS_A340_34_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# KJFK_A330_06R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# KJFK_A330_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->18
# KJFK_A330_23_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->20
# KJFK_A330_32_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# KJFK_A330_34_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# KJFK_A340_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# KJFK_A340_34_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# KLAX_A340_16_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->11
# KLAX_A340_34_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->9
# KMIA_A330_16_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# KMIA_A330_32_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# KMIA_A340_16_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# KMIA_A340_34_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# KORD_A330_16_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->11
# KORD_A330_32_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->11
# KORD_A330_34_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# KORD_A340_16_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# KORD_A340_34_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# KSFO_A340_16_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# KSFO_A340_34_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LEBL_A319/20/21_23_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->34
# LEBL_A319/20/21_28_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LEBL_A319/20/21_32_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LEMD_A319/20/21_10_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# LEMD_A319/20/21_16_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LEMD_A319/20/21_28_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->21
# LLBG_A330_10_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LLBG_A330_16_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# LLBG_A330_26L_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LLBG_A330_28_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->18
# LLBG_A330_32_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->30
# LLBG_A330_34_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# LLBG_A340_10_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# LLBG_A340_16_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LLBG_A340_28_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# LLBG_A340_34_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# LSGG_A319/20/21_07R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# LSGG_A319/20/21_10_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->29
# LSGG_A319/20/21_25L_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# LSGG_A319/20/21_27L_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSGG_A319/20/21_27R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->5
# LSGG_A319/20/21_28_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->46
# LSGG_A319/20/21_32_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->25
# LSGG_A319/20/21_34_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSGG_A330_04L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->21
# LSGG_A330_13R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LSGG_A330_22R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->20
# LSGG_A330_31L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# LSZH_A319/20/21_01L_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->10
# LSZH_A319/20/21_07R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->25
# LSZH_A319/20/21_09R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->18
# LSZH_A319/20/21_15L_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->11
# LSZH_A319/20/21_18L_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->10
# LSZH_A319/20/21_19R_2-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->19
# LSZH_A319/20/21_23_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->32
# LSZH_A319/20/21_24_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A319/20/21_25L_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A319/20/21_25R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# LSZH_A319/20/21_27L_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# LSZH_A319/20/21_27R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->17
# LSZH_A330_04L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->24
# LSZH_A330_04R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A330_06L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LSZH_A330_06R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->10
# LSZH_A330_08R_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# LSZH_A330_12L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# LSZH_A330_12R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->18
# LSZH_A330_12_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# LSZH_A330_12_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# LSZH_A330_13R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A330_14L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# LSZH_A330_14_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# LSZH_A330_15R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->17
# LSZH_A330_22L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->2
# LSZH_A330_22L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A330_22R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->17
# LSZH_A330_24L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->22
# LSZH_A330_24R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# LSZH_A330_26_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->20
# LSZH_A330_27_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->13
# LSZH_A330_28_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->10
# LSZH_A330_30L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->3
# LSZH_A330_30R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->19
# LSZH_A330_30_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->18
# LSZH_A330_31L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->9
# LSZH_A330_32L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->10
# LSZH_A330_32R_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# LSZH_A330_33L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->10
# LSZH_A340_01R_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# LSZH_A340_03L_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->11
# LSZH_A340_04L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# LSZH_A340_04R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LSZH_A340_06R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_06R_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_08L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_08R_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A340_10L_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_10R_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_10_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_12_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LSZH_A340_12_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_13R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->3
# LSZH_A340_14L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->19
# LSZH_A340_15R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->22
# LSZH_A340_21R_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A340_22L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# LSZH_A340_22L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# LSZH_A340_22R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A340_24L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->6
# LSZH_A340_24L_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->14
# LSZH_A340_24R_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# LSZH_A340_25R_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# LSZH_A340_26_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A340_27_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->9
# LSZH_A340_28L_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A340_28R_7-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->8
# LSZH_A340_28_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# LSZH_A340_30_4-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->12
# LSZH_A340_32L_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# LSZH_A340_32R_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# LSZH_A340_33L_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->19
# OMDB_A330_10_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# OMDB_A330_16_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->15
# OMDB_A330_26_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->47
# OMDB_A330_28_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->4
# OMDB_A330_32_5-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->7
# OOMS_A330_12R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->33
# OOMS_A330_30R_1-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->33
# VABB_A330_16_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->16
# VABB_A330_34_6-->FUEL_QUANTITY_KILOGRAMS_rollstart-->bins -->1
# CYUL_A330_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# CYUL_A330_28_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# CYUL_A330_32_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# CYUL_A340_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EBBR_A319/20/21_28_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EBBR_A319/20/21_32_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EGLL_A319/20/21_10_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EGLL_A319/20/21_23_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EGLL_A319/20/21_28_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EGLL_A319/20/21_32_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EGLL_A319/20/21_34_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EHAM_A319/20/21_10_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EHAM_A319/20/21_28_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# EHAM_A319/20/21_32_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# ESSA_A319/20/21_10_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# ESSA_A319/20/21_16_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# ESSA_A319/20/21_28_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# ESSA_A319/20/21_32_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# ESSA_A319/20/21_34_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# FKKD_A330_10_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# FKKD_A330_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# FKKD_A330_19_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# FKKD_A330_28_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# FKKD_A330_32_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# FKYS_A330_12_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# HKJK_A330_10_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# HKJK_A330_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KBOS_A330_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KBOS_A330_32_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KBOS_A340_10_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KBOS_A340_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KBOS_A340_28_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KBOS_A340_34_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A330_06R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A330_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A330_23_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A330_32_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A330_34_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A340_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KJFK_A340_34_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KLAX_A340_16_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KLAX_A340_34_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KMIA_A330_16_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KMIA_A330_32_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KMIA_A340_16_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KMIA_A340_34_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KORD_A330_16_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KORD_A330_32_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KORD_A330_34_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KORD_A340_16_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KORD_A340_34_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KSFO_A340_16_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# KSFO_A340_34_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LEBL_A319/20/21_23_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LEBL_A319/20/21_28_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LEBL_A319/20/21_32_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LEMD_A319/20/21_10_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LEMD_A319/20/21_16_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LEMD_A319/20/21_28_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A330_10_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A330_16_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A330_26L_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A330_28_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A330_32_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A330_34_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A340_10_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A340_16_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A340_28_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LLBG_A340_34_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_07R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_10_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_25L_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_27L_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_27R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_28_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_32_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A319/20/21_34_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A330_04L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A330_13R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A330_22R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSGG_A330_31L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_01L_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_07R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_09R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_15L_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_18L_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_19R_2-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_23_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_24_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_25L_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_25R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_27L_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A319/20/21_27R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_04L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_04R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_06L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_06R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_08R_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_12L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_12R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_12_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_12_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_13R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_14L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_14_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_15R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_22L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_22L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_22R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_24L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_24R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_26_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_27_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_28_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_30L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_30R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_30_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_31L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_32L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_32R_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A330_33L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_01R_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_03L_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_04L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_04R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_06R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_06R_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_08L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_08R_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_10L_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_10R_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_10_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_12_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_12_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_13R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_14L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_15R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_21R_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_22L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_22L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_22R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_24L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_24L_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_24R_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_25R_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_26_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_27_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_28L_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_28R_7-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_28_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_30_4-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_32L_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_32R_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# LSZH_A340_33L_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OMDB_A330_10_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OMDB_A330_16_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OMDB_A330_26_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OMDB_A330_28_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OMDB_A330_32_5-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OOMS_A330_12R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# OOMS_A330_30R_1-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# VABB_A330_16_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]
# VABB_A330_34_6-->AIR_TEMP_OUTSIDE_CELSIUS-->bins -->[0, 26.666666666666668, 1000]

# %%
#some preparation for group analysis
df_schedule_grouped = pd.DataFrame()
grouping_criteria = ["APT_AIRCRAFT_RUNWAY_STAGE", "HEAD_WIND_KNOTS_liftoff_BIN", "FUEL_QUANTITY_KILOGRAMS_rollstart_BIN", "AIR_TEMP_OUTSIDE_CELSIUS_BIN"] 
df_schedule_grouped = df_schedule.reset_index().set_index(grouping_criteria+["FLIGHT_ID"]).groupby(by=grouping_criteria)
min_flight_count = 7

#plot relationship of actual N1 to actual ground roll distance for a given weight group, weather group, runway group, aircraft type
#loop through the groups
df_schedule_grouped_filtered = df_schedule_grouped.filter(lambda x: x['N1'].count() >= min_flight_count).reset_index(["FLIGHT_ID"])

x = 'DISTANCE_FROM_RUNWAY_END_liftoff'
y = 'N1'
    
fig = px.scatter(
    df_schedule_grouped_filtered
    , title='CFDR actual N1 vs actual ground roll distance for<br>a given temperature/weight/wind/runway/aircraft group<br>'+ 'min flight count per group: ' + str(min_flight_count)
        + '<br>head winds within: ' + str(head_wind_bin_width) + 'knots'
        + '<br>Temperature Category 0 means below 80 Degrees Farenheit'
    , x=x
    , y=y
    , color=df_schedule_grouped_filtered.index.to_series()
    , trendline = 'ols'
    , labels = {'DISTANCE_FROM_RUNWAY_END_liftoff':'Distance in feet from deparing runway end at liftoff as stated in CFDR',
                'N1':'Throttle setting at liftoff',
#                 'APT_AIRCRAFT_RUNWAY_STAGE': 'Airport / Aicraft Type / Runway / Stage Length ID'
               }
#     , hover_data= ['FLIGHT_ID']
)
fig.layout.yaxis.update(range=(80,100))
fig.layout.xaxis.update(range=(5000,11000))
fig.layout.legend.update(title = "Airport / Aicraft Type / Runway / Stage Length ID<br>, Headwind Category, Weight Category, Air Temp Category")
file = fig.to_html()
with open(filepath+'\\N1_distance_correlation.html', 'w') as f:
    f.write(file)
    
df_schedule_bins["FUEL_QUANTITY_KILOGRAMS_rollstart_BIN_WIDTH"] = df_schedule_bins.FUEL_QUANTITY_KILOGRAMS_rollstart.apply(lambda x: x[1] - x[0])

# %%
resulting_groups = df_schedule_grouped_filtered.reset_index(level="APT_AIRCRAFT_RUNWAY_STAGE").APT_AIRCRAFT_RUNWAY_STAGE.unique()#.to_list()

pd.DataFrame(df_schedule_bins.FUEL_QUANTITY_KILOGRAMS_rollstart_BIN_WIDTH.loc[list(resulting_groups)])

#TODO: get the actual bin into the legend
df_schedule_grouped_filtered.index.to_frame().drop(
    columns=["APT_AIRCRAFT_RUNWAY_STAGE", "HEAD_WIND_KNOTS_liftoff_BIN", "FUEL_QUANTITY_KILOGRAMS_rollstart_BIN", "AIR_TEMP_OUTSIDE_CELSIUS_BIN"]
    , axis=1).join(df_schedule_bins).HEAD_WIND_KNOTS_liftoff.to_frame().reset_index()

# %%
detection_overview_plot = scatter_plot(df_schedule[df_schedule.liftoff_detection_quality_categorized.notna() == True], "liftoff_detection_quality_categorized")
detection_overview_plot.show()
plot_html = detection_overview_plot.to_html()
with open(filepath+'\\plot_detection_overview.html', 'w') as f:
    f.write(plot_html)
# Out:
# <div>                            <div id="74cbf681-58a3-4e47-99f8-d325b1b4f4b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74cbf681-58a3-4e47-99f8-d325b1b4f4b7")) {                    Plotly.newPlot(                        "74cbf681-58a3-4e47-99f8-d325b1b4f4b7",                        [{"customdata": [[1001880], [1003166], [1003309], [1003324], [1003611], [1003613], [1003796], [1003798], [1004138], [1004607], [1004704], [1004852], [1004926], [1005250], [1005429], [1005624], [1006171], [1006598], [1006602], [1006621], [1006890], [1007232], [1007819], [1008328], [1008354], [1008687], [1008891], [1008910], [1009079], [1009486], [1009488], [1009880], [1009952], [1009974], [1009975], [1010242], [1010494], [1010767], [1011130], [1011492], [1011526], [1011527], [1011529], [1011544], [1011946], [1012202], [1012213], [1012250], [1012375], [1012669], [1012740], [1012879], [1013131], [1013275], [1013278], [1013370], [1013802], [1013804], [1013808], [1014079], [1014182], [1014581], [1015246], [1015247], [1015432], [1016226], [1016265], [1016743], [1016782], [1017420], [1017554], [1018065], [1018073], [1018160], [1018414], [1018420], [1018467], [1018518], [1018841], [1019101], [1019107], [1019108], [1019111], [1019158], [1019276], [1019349], [1019487], [1019498], [1019513], [1019635], [1020065], [1020085], [1020115], [1020217], [1020586], [1020592], [1021567], [1021571], [1021634], [1021683], [1021689], [1021706], [1021710], [1021729], [1021768], [1021931], [1021950], [1021962], [1021973], [1022171], [1022201], [1022205], [1022207], [1022319], [1022320], [1022653], [1022690], [1022695], [1022699], [1023007], [1023011], [1023135], [1023137], [1023265], [1023583], [1023611], [1023879], [1023894], [1024100], [1024113], [1024123], [1024129], [1024205], [1025010], [1025018], [1025338], [1025416], [1025543], [1025609], [1025980], [1026036], [1026271], [1026317], [1026479], [1026791], [1026795], [1026802], [1026869], [1026918], [1026978], [1027049], [1028415], [1028458], [1028459], [1028581], [1028582], [1028659], [1028911], [1029010], [1029106], [1029132], [1029179], [1029339], [1029403], [1029721], [1029729], [1030619], [1030882], [1031308], [1031411], [1031459], [1031975], [1031976], [1031978], [1031997], [1031998], [1032007], [1032310], [1032370], [1032396], [1033032], [1033035], [1033155], [1033738], [1033768], [1033821], [1034632], [1034718], [1034719], [1034754], [1034756], [1034764], [1034905], [1035758], [1035780], [1036166], [1036267], [1036304], [1036306], [1036376], [1036529], [1036733], [1036736], [1036764], [1036792], [1036821], [1037139], [1037370], [1037548], [1037688], [1038237], [1038850], [1038852], [1038904], [1039030], [1039415], [1039619], [1039795], [1039932], [1040034], [1040214], [1040215], [1040342], [1040349], [1040350], [1040551], [1041124], [1042011], [1042067], [1042459], [1042578], [1042667], [1042679], [1042887], [1042977], [1042979], [1043082], [1043601], [1043686], [1043694], [1043695], [1043927], [1043928], [1044242], [1044269], [1044363], [1044365], [1045199], [1045407], [1045517], [1046251], [1046270], [1046273], [1046411], [1046684], [1046688], [1047391], [1047451], [1048029], [1048034], [1048243], [1049779], [1104065], [1104538], [1104615], [1105050], [1105051], [1105216], [1105262], [1105469], [1105602], [1105678], [1105929], [1105930], [1105931], [1106065], [1106111], [1106636], [1106686], [1106808], [1106868], [1106929], [1106977], [1107377], [1107406], [1107414], [1107415], [1107587], [1107685], [1108140], [1108308], [1108311], [1109604], [1109718], [1110039], [1110059], [1110063], [1110124], [1110235], [1110240], [1110241], [1110246], [1111127], [1111196], [1111253], [1111859], [1112051], [1112052], [1112261], [1112507], [1113060], [1113063], [1113064], [1113230], ...

# %%
#use group to highlight the groups that merit further investigation
detection_plot_by_group = scatter_plot(df_schedule)
detection_plot_by_group.show()
plot_html = detection_plot_by_group.to_html()
with open(filepath+'\\plot_detection_by_group.html', 'w') as f:
    f.write(plot_html)
# Out:
# <div>                            <div id="2739d00d-3bbf-460a-99c2-803d347010e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2739d00d-3bbf-460a-99c2-803d347010e0")) {                    Plotly.newPlot(                        "2739d00d-3bbf-460a-99c2-803d347010e0",                        [{"customdata": [[1001880], [1003324], [1003802], [1004926], [1007232], [1008415], [1008910], [1009975], [1011245], [1012250], [1013270], [1014909], [1015420], [1016265], [1016886], [1017555], [1018160], [1022831], [1023905], [1025019], [1028459], [1029106], [1043692], [1106065], [1109718], [1110039], [1110235], [1111253], [1112489], [1114062], [1114484], [1118690], [1119260], [1120537], [1122015], [1122019], [1122684], [1123749], [1123861], [1124373], [1127411], [1128101], [1128722], [1132706], [1138438], [1139019], [1140443], [1141779]], "hovertemplate": "Airport / Aicraft Type / Runway / Stage Length ID=LSZH_A330_32R_6<br>As stated in CFDR=%{x}<br>As detected from trajectory=%{y}<br>FLIGHT_ID=%{customdata[0]}<extra></extra>", "legendgroup": "LSZH_A330_32R_6", "marker": {"color": "#636efa", "opacity": 0.6, "symbol": "circle"}, "mode": "markers", "name": "LSZH_A330_32R_6", "showlegend": true, "type": "scattergl", "x": [6194.989312114829, 6061.85277172933, 6660.6379097861, 6079.10031030436, 5800.03071635918, 5518.45621455687, 5698.21208165553, 6330.197571771861, 5837.7690004913, 5821.19391626981, 5469.21663143455, 6264.543980288559, 6100.81184346072, 6351.62979162228, 5653.4374833700795, 5759.952614567471, 6100.81184346072, 5743.14718951292, 6363.57724188418, 5990.22372149323, 6205.7126543063705, 6538.3261725917, 7240.00952501405, 6772.54391037397, 6538.3261725917, 6430.348185854929, 6538.3261725917, 7192.398688413051, 7300.499619136021, 7314.682400600501, 7113.82732188692, 6694.243325928929, 6739.2811364569, 7206.02791291245, 6958.20443126859, 6816.48843613319, 6616.89867589379, 6396.49136083454, 6226.9163929794495, 6382.525329998579, 6694.243325928929, 6349.92285563684, 7348.216449910691, 6352.984869883299, 6928.65622905571, 6041.394364594449, 6538.3261725917, 5465.98786073496], "xaxis": "x", "y": [6193.85974328077, 6060.72313351434, 6395.35923765827, 6077.97069157322, 5798.901120584859, 5780.09872377959, 5697.08244909954, 6329.06795026818, 6391.699245839301, 5820.0642925966695, 8669.19219134899, 6544.71793709818, 9451.92876798992, 6350.50025390307, 5933.155908438829, 9315.76837546121, 6099.68231651428, 8483.60469592088, 7801.4258906773, 7959.176055958929, 6204.58304769501, 6537.195959523149, 7502.74067508822, 6771.413934349411, 6537.195959523149, 6429.21852015926, 6537.195959523149, 7191.2685330000295, 7610.859633374859, 7624.6014595816005, 7112.697098836891, 6693.11328298796, 6738.14888321908, 7780.067175705309, 7268.33368397514, 7079.5057325036705, 6615.76853627978, 6131.07022114415, 6225.7858347252, 6381.394948909599, 6693.11328298796, 6659.50558080838, 7347.086442173579, 6351.855104837509, 6927.5264119596895, 5805.8877614721, 6537.195959523149, 5698.04538528183], "yaxis": "y"}, {"customdata": [[1001898], [1003604], [1004232], [1008912], [1009486], [1011529], [1013803], [1014583], [1018064], [1018414], [1023441], [1028912], [1042978], [1105931], [1122009], [1141997], [1142552], [1144662], [1148597], [1149733], [1154149], [1154705]], "hovertemplate": "Airport / Aicraft Type / Runway / Stage Length ID=LSZH_A340_27_6<br>As stated in CFDR=%{x}<br>As detected from trajectory=%{y}<br>FLIGHT_ID=%{customdata[0]}<extra></extra>", "legendgroup": "LSZH_A340_27_6", "marker": {"color": "#EF553B", "opacity": 0.6, "symbol": "circle"}, "mode": "markers", "name": "LSZH_A340_27_6", "showlegend": true, "type": "scattergl", "x": [7603.818733796021, 7317.351332861591, 7307.547416405079, 7657.06400010577, 7498.241065649541 ...

# %%
#plot relationship of actual N1 to detected ground roll distance for a given weight, weather, runway, aircraft type
#plot relationship of actual N1 to detected N1 for a given weight, weather, runway, aircraft type

# %%
df_high_qual_lift = df.join(flights_with_very_high_liftoff_detection_quality,how = 'inner')
fp = plot_metrics_for_individual_flights(df_high_qual_lift, -1)
wb.open(url=fp)

# %%
#focus in on one pair of flights
#df_schedule = df_schedule.loc[[1124373, 1128101],:]

# %%
#two flights with similar stated liftoff point 
flights = [1128101, 1124373]
plot_metrics_for_individual_flights(df.loc[flights,])

# %%
fig = px.scatter(
    df_rollstart
    , title='Start of takeoff roll, distance from runway end (feet)'
    , x='DISTANCE_FROM_RUNWAY_END'
    , y='DISTANCE_FROM_RUNWAY_END_AT_DETECTED_START_OF_TAKEOFF'
    , color="APT_AIRCRAFT_RUNWAY_STAGE.1" 
    , labels = {'DISTANCE_FROM_RUNWAY_END':'As stated in CFDR',
                'DISTANCE_FROM_RUNWAY_END_AT_DETECTED_START_OF_TAKEOFF':'As detected from trajectory',
                'APT_AIRCRAFT_RUNWAY_STAGE.1': 'Airport / Aicraft Type / Runway / Stage Length ID'
               }
)

fig.update_yaxes(
    scaleanchor = "x",
    scaleratio = 1,
  )

fig.show()

file = fig.to_html()
with open(filepath+'\plot_rollstart.html', 'w') as f:
    f.write(file)

# %%
fig_px = px.scatter(
    df_liftoff
    , title='Liftoff distance from runway end (feet)'
    , x='DISTANCE_FROM_RUNWAY_END'
    ,y='MSL_ALT'
    , color = "FLIGHT_ID"
    , labels = {'DISTANCE_FROM_RUNWAY_END':'Distance from runway end (feet)',
                'MSL_ALT':'Altitude above mean sea level (feet)',
                'APT_AIRCRAFT_RUNWAY_STAGE.1': 'Airport / Aicraft Type / Runway / Stage Length ID'
               }
)

file = fig_px.to_html()
with open(filepath+'\plot_high_quality_by_flight.html', 'w') as f:
    f.write(file)
    
fig_px.show()
